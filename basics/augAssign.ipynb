# %%
num = 12
print(f"Initial: {num}")
num += 6
print(f"add: {num}")
num -= 3
print(f"Sub: {num}")
print(f"Current: {num}")
num *= 2
print(f"Multiply by 2: {num}")
# Out:
# Initial: 12
# add: 18
# Sub: 15
# Current: 15
# Multiply by 2: 30

# %%
# String Addition
greet = 'Hello'
greet += ' World'
print(greet)

greet *= 4
print(greet)
# Out:
# Hello World
# Hello WorldHello WorldHello WorldHello World
