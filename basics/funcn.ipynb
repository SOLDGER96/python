# %%
name = input('What\'s your name?')
print('Hola,', name)
# Out:
# Hola, Jod

# %%
# Custom Function
def hello():
    print('Hello World')

hello()

def calSum(a, b):
    return(a + b)

print(calSum(2, 4))
# Out:
# Hello World
# 6
