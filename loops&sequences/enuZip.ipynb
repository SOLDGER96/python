# %%
languages = ['Spanish', 'English', 'Russian', 'Chinese']

index = 0

for language in languages:
    print(f'Index {index} and language {language}')
    index += 1
# Out:
# Index 0 and language Spanish
# Index 1 and language English
# Index 2 and language Russian
# Index 3 and language Chinese

# %%
languages = ['Spanish', 'English', 'Russian', 'Chinese']
list(enumerate(languages))
# Out:
# [(0, 'Spanish'), (1, 'English'), (2, 'Russian'), (3, 'Chinese')]

# %%
for index, language in enumerate(languages):
    print(f'Index {index} and language {language}')
# Out:
# Index 0 and language Spanish
# Index 1 and language English
# Index 2 and language Russian
# Index 3 and language Chinese

# %% [markdown]
# ##### pass a list of developers and ids to the zip() function and convert its returned value into a list with the list() function

# %%
dev = ['agnelo', 'vasu', 'tanmay']
id = [10, 29, 96]
list(zip(id, dev))
# Out:
# [(10, 'agnelo'), (29, 'vasu'), (96, 'tanmay')]

# %%
dev = ['agnelo', 'vasu', 'tanmay']
id = [10, 29, 96]

for name, ids in zip(dev, id):
    print(f'Name: {name} | ID: {ids}\n')
# Out:
# Name: agnelo | ID: 10
#
# Name: vasu | ID: 29
#
# Name: tanmay | ID: 96
