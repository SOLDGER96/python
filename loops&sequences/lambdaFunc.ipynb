# %%
num = [1,2,3,4,5,6]
evenNum = list(filter(lambda x: x % 2 == 0, num))
print(evenNum)
# Out:
# [2, 4, 6]

# %%
num = [1,2,3,4,5]
square = lambda x: x ** 2
squares = list(map(square, num))
print(squares)
# Out:
# [1, 4, 9, 16, 25]
