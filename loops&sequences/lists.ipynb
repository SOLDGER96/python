# %%
cities = ['kudal', 'vengurla', 'malwan']
print(cities[0])
print(cities[-1])
len(cities)
# Out:
# kudal
# malwan
# 3

# %%
name = 'agnelo'
list(name)
# Out:
# ['a', 'g', 'n', 'e', 'l', 'o']

# %%
num = [1, 2, 3, 4, 5]
len(num)
# Out:
# 5

# %%
# Replacing a item from list
names = ['vasu', 'pranav', 'ayush', 'kshtj']
names[0] = 'harshu'
print(names)
# Out:
# ['harshu', 'pranav', 'ayush', 'kshtj']

# %%
# Deleting a item from list
del names[1]
print(names)
# Out:
# ['harshu', 'ayush', 'kshtj']

# %%
# Presence of item in a list
programming_languages = ['Python', 'Java', 'C++', 'Rust']
print('Rust' in programming_languages)
print('go' in programming_languages)
# Out:
# True
# False

# %%
manInfo = ['harshu', 25, ['married', '15 may', 'confirm']]
print(manInfo[2])

# Accessing nested list
print(manInfo[2][2])
# Out:
# ['married', '15 may', 'confirm']
# confirm

# %%
# Assigning var name to index
dev = ['agnelo', 23, 'SAP dev']
name, age, job = dev
print(name)
print(age)
print(job)
# Out:
# agnelo
# 23
# SAP dev

# %%
dev = ['agnelo', 23, 'SAP dev']
name, *rest = dev
print(name)
print(rest)
# Out:
# agnelo
# [23, 'SAP dev']

# %%
names = ['one', 'two', 'three', 'four', 'five']
print(names[1:4])
# Out:
# ['two', 'three', 'four']

# %%
num = [1,2,3,4,5,6,7,8,9]
print(num[0::2])
# Out:
# [1, 3, 5, 7, 9]
