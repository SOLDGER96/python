# %%
str = "Hello World"
print(str[1:4])
print(str[:7])
print(str[7:])
print(str[:])
# Out:
# ell
# Hello W
# orld
# Hello World

# %%
# START : STOP : STEP INDEX
str = "Hello World"
print(str[0:11:2])
print(str[::-2])
# Out:
# HloWrd
# drWolH

# %%
#
