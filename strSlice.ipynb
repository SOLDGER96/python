# %%
str = "Hello World"
print(str[1:4])
print(str[:7])
print(str[7:])
print(str[:])
# Out:
# ell
# Hello W
# orld
# Hello World

# %%
# START : STOP : STEP INDEX
str = "Hello World"
print(str[0:11:2])
print(str[::-2])
# Out:
# HloWrd
# drWolH

# %%
# String Methods
print(str.upper())
print(str.lower())
# Out:
# HELLO WORLD
# hello world

# %%
# strip(): Returns a new string with the specified leading and 
# trailing characters removed. If no argument is passed it 
# removes leading and trailing whitespace.

str = '    Hello    '
print(str.strip())
# Out:
# Hello

# %%
# replace(old, new): Returns a new string with all 
# occurrences of old replaced by new.
str = 'Nigga Ayush'
strnew = str.replace('Nigga', 'Goro')
print(strnew)
# Out:
# Goro Ayush

# %%
# split(separator): Splits a string on a specified separator 
# into a list of strings. If no separator is specified, 
# it splits on whitespace.
str = "one two three four"
str = str.split()
print(str)
# Out:
# ['one', 'two', 'three', 'four']

# %%
# join(iterable): Joins elements of an iterable into a string 
# with a separator.
my_list = ['hello', 'world']

joined_my_str = ', '.join(my_list)
print(joined_my_str)
# Out:
# hello, world

# %%
# startswith(prefix): Returns a boolean indicating if a string 
# starts with the specified prefix.
my_str = 'hello world'
starts_with_hello = my_str.startswith('hello')
print(starts_with_hello) 

endsWith = my_str.endswith('World') # Everything is case sensitive
print(endsWith)
# Out:
# True
# False

# %%
# find(substring): Returns the index of the first occurrence of 
# substring, or -1 if it doesn't find one.
my_str = 'hello world'

world_index = my_str.find('world')
print(world_index)
# Out:
# 6

# %%
# count(substring): Returns the number of times a substring appears 
# in a string.
my_str = 'hello world'

o_count = my_str.count('o')
print(o_count)
# Out:
# 2

# %%
# capitalize(): Returns a new string with the first character capitalized and the other characters lowercased.
my_str = 'hello WoRld'

capitalized_my_str = my_str.capitalize()
print(capitalized_my_str)
# Out:
# Hello world

# %%
# title(): Returns a new string with the first letter of each word capitalized.
my_str = 'hello world'

title_case_my_str = my_str.title()
print(title_case_my_str)
# Out:
# Hello World
