# %%
import pdb

def divide(a, b):
    pdb.set_trace()
    return a/b

print(divide(10, 2))
# Out:
# > c:\users\india\appdata\local\temp\ipykernel_8724\4130402668.py(4)divide()
#
# a = 10
# b = 2
# a = 10
# b = 2
# a = 10
# b = 2
# a = 10
# b = 2
# *** Invalid argument: a/b
#       Usage: r(eturn)
# *** Invalid argument: a / b
#       Usage: r(eturn)
# *** Invalid argument: a / b
#       Usage: r(eturn)
# a = 10
# b = 2
# 5.0

# %%
def divide(a, b):
    res = a / b
    return res

print(divide(10, 2))
print(divide(15, 3))
